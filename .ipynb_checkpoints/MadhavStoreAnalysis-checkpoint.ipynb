# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
order=pd.read_csv('Orders.csv')

# %%
order.head()
# Out:
#   Order ID  Order Date CustomerName           State     City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi    Delhi
# 2  B-25973  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 3  B-25923  27-12-2018        Gopal     Maharashtra   Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh   Indore

# %%
pd.isnull(order)
# Out:
#      Order ID  Order Date  CustomerName  State   City
# 0       False       False         False  False  False
# 1       False       False         False  False  False
# 2       False       False         False  False  False
# 3       False       False         False  False  False
# 4       False       False         False  False  False
# ..        ...         ...           ...    ...    ...
# 495     False       False         False  False  False
# 496     False       False         False  False  False
# 497     False       False         False  False  False
# 498     False       False         False  False  False
# 499     False       False         False  False  False
#
# [500 rows x 5 columns]

# %%
order.isnull().sum()
# Out:
# Order ID        0
# Order Date      0
# CustomerName    0
# State           0
# City            0
# dtype: int64

# %%
detail=pd.read_csv('details.csv')

# %%
detail.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
# 2  B-25955    2927     146         8    Furniture         Bookcases
# 3  B-26093    2847     712         8  Electronics          Printers
# 4  B-25602    2617    1151         4  Electronics            Phones
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card
# 4  Credit Card

# %%
detail.shape
# Out:
# (1500, 7)

# %%
order.shape
# Out:
# (500, 5)

# %%
df_inner=pd.merge(order,detail,how='inner',on='Order ID')
df_left=pd.merge(order,detail,how='left',on='Order ID')
df_right=pd.merge(order,detail,how='right',on='Order ID')
df_outer=pd.merge(order,detail,how='outer',on='Order ID')

# %%
df_inner.shape
# Out:
# (1500, 11)

# %%
df_left.shape
# Out:
# (1500, 11)

# %%
df_right.shape
# Out:
# (1500, 11)

# %%
df_outer.shape
# Out:
# (1500, 11)

# %%
df_inner.isnull().sum()
# Out:
# Order ID        0
# Order Date      0
# CustomerName    0
# State           0
# City            0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# dtype: int64

# %%
df_inner.head()
# Out:
#   Order ID  Order Date CustomerName          State     City  Amount  Profit  \
# 0  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura    5729      64
# 1  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura     671     114
# 2  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura     443      11
# 3  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura      57       7
# 4  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura     227      48
#
#    Quantity     Category Sub-Category  PaymentMode
# 0        14    Furniture       Chairs          EMI
# 1         9  Electronics       Phones  Credit Card
# 2         1     Clothing        Saree          COD
# 3         2     Clothing        Shirt          UPI
# 4         5     Clothing        Stole          COD

# %%
# copy df in another 
df=df_inner.copy()

# %%
df['Date']=pd.to_datetime(df['Order Date'],dayfirst=True)

# %%
df['MonthName']=df['Date'].dt.month_name()
df['day'] = df['Date'].dt.day
df['year']=df['Date'].dt.year
df['daysname']=df['Date'].dt.day_name()

# %%
df.head()
# Out:
#   Order ID  Order Date CustomerName          State     City  Amount  Profit  \
# 0  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura    5729      64
# 1  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura     671     114
# 2  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura     443      11
# 3  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura      57       7
# 4  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura     227      48
#
#    Quantity     Category Sub-Category  PaymentMode       Date MonthName  day  \
# 0        14    Furniture       Chairs          EMI 2018-03-10     March   10
# 1         9  Electronics       Phones  Credit Card 2018-03-10     March   10
# 2         1     Clothing        Saree          COD 2018-03-10     March   10
# 3         2     Clothing        Shirt          UPI 2018-03-10     March   10
# 4         5     Clothing        Stole          COD 2018-03-10     March   10
#
#    year  daysname
# 0  2018  Saturday
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Order Date    1500 non-null   object
#  2   CustomerName  1500 non-null   object
#  3   State         1500 non-null   object
#  4   City          1500 non-null   object
#  5   Amount        1500 non-null   int64
#  6   Profit        1500 non-null   int64
#  7   Quantity      1500 non-null   int64
#  8   Category      1500 non-null   object
#  9   Sub-Category  1500 non-null   object
#  10  PaymentMode   1500 non-null   object
#  11  Date          1500 non-null   datetime64[ns]
#  12  MonthName     1500 non-null   object
#  13  day           1500 non-null   int32
#  14  year          1500 non-null   int32
#  15  daysname      1500 non-null   object
# dtypes: datetime64[ns](1), int32(2), int64(3), object(10)
# memory usage: 175.9+ KB

# %%
df.drop('Order Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Order ID CustomerName          State     City  Amount  Profit  Quantity  \
# 0  B-26055    Harivansh  Uttar Pradesh  Mathura    5729      64        14
# 1  B-26055    Harivansh  Uttar Pradesh  Mathura     671     114         9
# 2  B-26055    Harivansh  Uttar Pradesh  Mathura     443      11         1
# 3  B-26055    Harivansh  Uttar Pradesh  Mathura      57       7         2
# 4  B-26055    Harivansh  Uttar Pradesh  Mathura     227      48         5
#
#       Category Sub-Category  PaymentMode       Date MonthName  day  year  \
# 0    Furniture       Chairs          EMI 2018-03-10     March   10  2018
# 1  Electronics       Phones  Credit Card 2018-03-10     March   10  2018
# 2     Clothing        Saree          COD 2018-03-10     March   10  2018
# 3     Clothing        Shirt          UPI 2018-03-10     March   10  2018
# 4     Clothing        Stole          COD 2018-03-10     March   10  2018
#
#    daysname
# 0  Saturday
# 1  Saturday
# 2  Saturday
# 3  Saturday
# 4  Saturday

# %% [markdown]
# # EDA

# %% [markdown]
# # state wise analysis

# %%
# state wise analysis
df_state=df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_state,x='State',y='Amount',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\2086839129.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_state,x='State',y='Amount',palette='Set2')
# <Axes: xlabel='State', ylabel='Amount'>

# %%
df_state=df.groupby(['State'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_state,x='State',y='Quantity',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\4189884421.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_state,x='State',y='Quantity',palette='Set2')
# <Axes: xlabel='State', ylabel='Quantity'>

# %%
ax=sns.countplot(data=df,x='State')
sns.set(rc={'figure.figsize':(20,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df_state=df.groupby(['State'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.barplot(data=df_state,x='State',y='Quantity',palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\4036260215.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_state,x='State',y='Quantity',palette='Set2')

# %%
# state wise profit

df_state=df.groupby(['State'],as_index=False)['Profit'].sum().sort_values(by='Profit',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_state,x='State',y='Profit',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\881153619.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_state,x='State',y='Profit',palette='Set2')
# <Axes: xlabel='State', ylabel='Profit'>

# %%
df_state_category=df.groupby(['State','Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_state_category,x='State',y='Amount',hue='Category',palette='Set2')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# # city wise analysis

# %%
df_city=df.groupby(['City'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(20)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_city,x='City',y='Amount',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\263770089.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_city,x='City',y='Amount',palette='Set2')
# <Axes: xlabel='City', ylabel='Amount'>

# %%
df_city=df.groupby(['City'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False).head(20)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_city,x='City',y='Quantity',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\778364715.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_city,x='City',y='Quantity',palette='Set2')
# <Axes: xlabel='City', ylabel='Quantity'>

# %%
df_city=df.groupby(['City'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False).head(20)
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.barplot(data=df_city,x='City',y='Quantity',palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\2992322369.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_city,x='City',y='Quantity',palette='Set2')

# %%
df_city=df.groupby(['City'],as_index=False)['Profit'].sum().sort_values(by='Profit',ascending=False).head(20)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_city,x='City',y='Profit',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\3785784165.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_city,x='City',y='Profit',palette='Set2')
# <Axes: xlabel='City', ylabel='Profit'>

# %%
df.Category.unique()
# Out:
# array(['Furniture', 'Electronics', 'Clothing'], dtype=object)

# %%
df_category=df.groupby(['Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data=df_category,x='Category',y='Amount',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\588912041.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_category,x='Category',y='Amount',palette='Set2')
# <Axes: xlabel='Category', ylabel='Amount'>

# %%
df_category=df.groupby(['Category'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
ax=sns.barplot(data=df_category,x='Category',y='Quantity',palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\1498619688.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_category,x='Category',y='Quantity',palette='Set2')

# %%
df_category=df.groupby(['Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
df_category
# Out:
#       Category  Amount
# 1  Electronics  166267
# 0     Clothing  144323
# 2    Furniture  127181

# %%
cat=df_category.Category
amount=df_category.Amount
plt.pie(amount,labels=cat,autopct='%1.1f%%', startangle=90)
plt.title('sales Distribution by category')
plt.axis('equal')
plt.show()

# %%
cat=df_category.Category
amount=df_category.Amount
plt.pie(amount,labels=cat,autopct='%1.1f%%', startangle=90)
plt.title('sales Distribution by category')
#plt.axis('equal')
plt.show()

# %%
df_category=df.groupby(['Category'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)
df_category
# Out:
#       Category  Quantity
# 0     Clothing      3516
# 1  Electronics      1154
# 2    Furniture       945

# %%
quantity=df_category.Quantity
cat=df_category.Category
plt.pie(quantity,labels=cat,autopct='%1.1f%%', startangle=90)
plt.title('sales Distribution by category')
#plt.axis('equal')
plt.show()

# %% [markdown]
# # Distribution by sub category

# %%
df_sub_cat=df.groupby(['Sub-Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(15)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=df_sub_cat,x='Sub-Category',y='Amount',palette='Set2')
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\990368703.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_sub_cat,x='Sub-Category',y='Amount',palette='Set2')
# <Axes: xlabel='Sub-Category', ylabel='Amount'>

# %%
df_sub_cat=df.groupby(['Sub-Category'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False).head(15)
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.barplot(data=df_sub_cat,x='Sub-Category',y='Quantity',palette='Set2')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_12812\338985284.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df_sub_cat,x='Sub-Category',y='Quantity',palette='Set2')

# %%
df_sub_cat=df.groupby(['Sub-Category'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)

# %%
df_sub_cat=df.groupby(['Sub-Category'],as_index=False)[['Quantity','Amount']].sum().sort_values(by='Amount',ascending=False)
df_sub_cat
# Out:
#         Sub-Category  Quantity  Amount
# 9           Printers       291   59252
# 10             Saree       795   59094
# 1          Bookcases       297   56861
# 8             Phones       304   46119
# 3   Electronic Games       297   39168
# 2             Chairs       277   34222
# 16          Trousers       135   30039
# 15            Tables        61   22614
# 0        Accessories       262   21728
# 13             Stole       671   18546
# 5        Hankerchief       741   14294
# 4        Furnishings       310   13484
# 11             Shirt       271    7555
# 14           T-shirt       305    7382
# 6              Kurti       164    3361
# 7           Leggings       186    2106
# 12             Skirt       248    1946

# %%
df.shape
# Out:
# (1500, 15)

# %%
df.describe()
# Out:
#             Amount      Profit     Quantity                        Date  \
# count  1500.000000  1500.00000  1500.000000                        1500
# mean    291.847333    24.64200     3.743333  2018-06-14 21:56:09.600000
# min       4.000000 -1981.00000     1.000000         2018-01-01 00:00:00
# 25%      47.750000   -12.00000     2.000000         2018-03-08 18:00:00
# 50%     122.000000     8.00000     3.000000         2018-05-28 00:00:00
# 75%     326.250000    38.00000     5.000000         2018-10-01 00:00:00
# max    5729.000000  1864.00000    14.000000         2018-12-31 00:00:00
# std     461.924620   168.55881     2.184942                         NaN
#
#                day    year
# count  1500.000000  1500.0
# mean     14.929333  2018.0
# min       1.000000  2018.0
# 25%       8.000000  2018.0
# 50%      14.000000  2018.0
# 75%      22.000000  2018.0
# max      31.000000  2018.0
# std       8.612498     0.0

# %%
df.columns
# Out:
# Index(['Order ID', 'CustomerName', 'State', 'City', 'Amount', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'PaymentMode', 'Date',
#        'MonthName', 'day', 'year', 'daysname'],
#       dtype='object')

# %% [markdown]
# # Trend Analysis

# %%
# yearly trend analysis

yearly_sales=df.groupby('year')['Amount'].sum().reset_index()

plt.figure(figsize=(20,6))
sns.lineplot(x='year',y='Amount',data=yearly_sales,marker='o')
plt.title('Yearly sales trend')
plt.xlabel('Year')
plt.ylabel('Total Sales (Amount)')
plt.show()

# %%
# monthly sales trend

monthly_sales=df.groupby('MonthName')['Amount'].sum().reset_index()
plt.figure(figsize=(20,6))
sns.lineplot(x='MonthName',y='Amount',data=monthly_sales,marker='o')
plt.title('Monthly sales trend')
plt.xlabel('Month')
plt.ylabel('Total Sales (Amount)')
plt.show()

# %%
# Days wise trends

days_trend=df.groupby('daysname')['Amount'].sum().reset_index()
plt.figure(figsize=(20,6))
sns.lineplot(x='daysname',y='Amount',data=days_trend,marker='o')
plt.title('days sales trend')
plt.xlabel('daysname')
plt.ylabel('Total Sales (Amount)')
plt.show()

# %%
# daily sales by date and amount

daily_sales=df.groupby('Date')['Amount'].sum().reset_index()

plt.figure(figsize=(20,6))
sns.lineplot(x='Date',y='Amount',data=daily_sales,marker='o')
plt.title('Date sales trend')
plt.xlabel('Date')
plt.ylabel('Total Sales (Amount)')
plt.show()

# %%
#
